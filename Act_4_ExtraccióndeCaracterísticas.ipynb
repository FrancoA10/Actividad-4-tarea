# %%
# %pip install funpymodeling
#Instalamos librería para análisis de variables categóricas

# %%
#Importamos librerias requeridas
import pandas as pd

import numpy as nd

import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo scv desde equipo
from google.colab import files
files.upload()

# %%
#Codigo para visualizar todas las columnas
#Ajustar maximo de columnas
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Ret= pd.read_excel("microretailer_mit_lift_lab.xlsx")
Micro_Ret

# %%
#Identificar valores nulos por columna
valores_nulos=Micro_Ret.isnull().sum()
valores_nulos

# %%
#Verificamos la informacion del dataframe
Micro_Ret.info()

# %%
#Imprimimos los primeros 5 registros del Dataframe
Micro_Ret.head()

# %%
#Se obtiene un analisis univariado de las variables categoricas
freq_tbl(Micro_Ret)

# %%
#Se obtiene un analisis univariado de las variables categoricas, una en especifico
tab1= freq_tbl(Micro_Ret["214_customer_relationship_tools"])
tab1

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
Filtro1= tab1[tab1["frequency"]>1]
Filtro1
# Out:
#    214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                   Redes sociales         27    0.157895         0.284211
# 1                 Aplicación móvil         21    0.122807         0.505263
# 2                          Ninguna         20    0.116959         0.715789
# 3  Aplicación móvil,Redes sociales         13    0.076023         0.852632
# 4                         Cuaderno          6    0.035088         0.915789

# %%
#Ajusto indice para DATAFRAME
Filtro_index=Filtro1.set_index("214_customer_relationship_tools")
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 214_customer_relationship_tools
# Redes sociales                          27    0.157895         0.284211
# Aplicación móvil                        21    0.122807         0.505263
# Ninguna                                 20    0.116959         0.715789
# Aplicación móvil,Redes sociales         13    0.076023         0.852632
# Cuaderno                                 6    0.035088         0.915789

# %%
#Realizamos la grafica de pastel del Dataframe filtrado
Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-69-89bbb7ad8526> in <cell line: 2>()
#       1 #Realizamos la grafica de pastel del Dataframe filtrado
# ----> 2 Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#filtro PARA las vaiables cuantitativas
Mic2=Micro_Ret.iloc[:,[52,53,55,63,64,66,67,68,69,70,71,72,73,74,75,76,77,79,80,81]]#VAIRABLES cuantitativas, columnnas
Mic2

# %%
Mic2.info()

# %%
#Sustituir valores nulos por un string en  concreto
Mic2["38_average_margin_profits"] =Mic2["38_average_margin_profits"].fillna("NONE")#1
Mic2["193_sales_planning_tools"] =Mic2["193_sales_planning_tools"].fillna("NONE")#2
Mic2["60_services"] =Mic2["60_services"].fillna("NONE")#3
Mic2["311_topups"] =Mic2["311_topups"].fillna("NONE")#4
Mic2["66_percentaje_services_income"] =Mic2["66_percentaje_services_income"].fillna("NONE")#5
Mic2["64_comission_services"] =Mic2["64_comission_services"].fillna("NONE")#6
Mic2["312_payment_of_utilities"] =Mic2["312_payment_of_utilities"].fillna("NONE")#7
Mic2["313_home_deliveries"] =Mic2["313_home_deliveries"].fillna("NONE")#8
Mic2["314_reception_delivery_packages"] =Mic2["314_reception_delivery_packages"].fillna("NONE")#9
Mic2["42_willingness_share_inventory_data_suppliers"] =Mic2["42_willingness_share_inventory_data_suppliers"].fillna("NONE")#10
Mic2["44_willingness_inventory_management_suppliers"] =Mic2["44_willingness_inventory_management_suppliers"].fillna("NONE")#11
Mic2["45_willingness_reorder_suppliers"] =Mic2["45_willingness_reorder_suppliers"].fillna("NONE")#12
Mic2["46_willingness_reorder_suppliers_variety"] =Mic2["46_willingness_reorder_suppliers_variety"].fillna("NONE")#13
Mic2["47_willingness_reorder_suppliers_lower_prices"] =Mic2["47_willingness_reorder_suppliers_lower_prices"].fillna("NONE")#14
Mic2["43_willingness_share_sales_data_suppliers"] =Mic2["43_willingness_share_sales_data_suppliers"].fillna("NONE")#15
Mic2["58_willingness_share_sales_data_mse"] =Mic2["58_willingness_share_sales_data_mse"].fillna("NONE")#16
Mic2["59_willingness_share_sales_data_mse_better_prices"] =Mic2["59_willingness_share_sales_data_mse_better_prices"].fillna("NONE")#17
Mic2["185_place_orders_suppliers"] =Mic2["185_place_orders_suppliers"].fillna("NONE")#18
Mic2["53_special_conditions_suppliers"] =Mic2["53_special_conditions_suppliers"].fillna("NONE")#19
Mic2["278_credit_interest"] =Mic2["278_credit_interest"].fillna("NONE")#20

# %%
#Identificar valores nulos por columna
valores_nulosM2=Mic2.isnull().sum()
valores_nulosM2
# Out:
# 38_average_margin_profits                            0
# 193_sales_planning_tools                             0
# 60_services                                          0
# 64_comission_services                                0
# 66_percentaje_services_income                        0
# 311_topups                                           0
# 312_payment_of_utilities                             0
# 313_home_deliveries                                  0
# 314_reception_delivery_packages                      0
# 42_willingness_share_inventory_data_suppliers        0
# 44_willingness_inventory_management_suppliers        0
# 45_willingness_reorder_suppliers                     0
# 46_willingness_reorder_suppliers_variety             0
# 47_willingness_reorder_suppliers_lower_prices        0
# 43_willingness_share_sales_data_suppliers            0
# 58_willingness_share_sales_data_mse                  0
# 59_willingness_share_sales_data_mse_better_prices    0
# 185_place_orders_suppliers                           0
# 53_special_conditions_suppliers                      0
# 278_credit_interest                                  0
# dtype: int64

# %%
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_1= freq_tbl(Micro_Ret["38_average_margin_profits"])
Filtro_1= tab_1[tab_1["frequency"]>1]
Filtro_index_1=Filtro_1.set_index("38_average_margin_profits")
#Identificar valores nulos por columna

#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-f2b706cf47ac> in <cell line: 12>()
#      10 #valores_nulos_1
#      11 #Realizamos le pastel del Dataframe filtrado
# ---> 12 Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_2= freq_tbl(Micro_Ret["193_sales_planning_tools"])
Filtro_2= tab_2[tab_2["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_2=Filtro_2.set_index("193_sales_planning_tools")#ajustamos esta columna como una de tipo indice
Filtro_index_2
#Realizamos le pastel del Dataframe filtrado
Filtro_index_2["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-7120d0af4a1e> in <cell line: 8>()
#       6 Filtro_index_2
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_2["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_3= freq_tbl(Micro_Ret["53_special_conditions_suppliers"])
Filtro_3= tab_3[tab_3["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_3=Filtro_3.set_index("53_special_conditions_suppliers")#ajustamos esta columna como una de tipo indice
Filtro_index_3
#Realizamos le pastel del Dataframe filtrado
Filtro_index_3["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-32-21a96b66421e> in <cell line: 8>()
#       6 Filtro_index_3
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_3["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_4= freq_tbl(Micro_Ret["60_services"])
Filtro_4= tab_4[tab_4["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_4=Filtro_4.set_index("60_services")#ajustamos esta columna como una de tipo indice
Filtro_index_4
#Realizamos le pastel del Dataframe filtrado
Filtro_index_4["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-f9c415633aab> in <cell line: 8>()
#       6 Filtro_index_4
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_4["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_5= freq_tbl(Micro_Ret["64_comission_services"])
Filtro_5= tab_5[tab_5["frequency"]>1]
Filtro_index_5=Filtro_5.set_index("64_comission_services")
Filtro_index_5
#Realizamos le pastel del Dataframe filtrado
Filtro_index_5["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-1821a6859251> in <cell line: 8>()
#       6 Filtro_index_5
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_5["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
 #Obtengo un analisis univariado de las variables categoricas, una slecionada
 #Obtengo un analisis univariado de las variables categoricas, una en especifico
 tab_6= freq_tbl(Micro_Ret["278_credit_interest"])
 Filtro_6= tab_6[tab_6["frequency"]>1]
 Filtro_index_6=Filtro_6.set_index("278_credit_interest")
 Filtro_index_6
# Out:
#                      frequency  percentage  cumulative_perc
# 278_credit_interest
# 0                           29    0.169591         0.763158
# 3-5%                         4    0.023392         0.868421
# 1-2%                         3    0.017544         0.947368

# %%
 #Realizamos le pastel del Dataframe filtrado
 Filtro_index_6["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-8031ff062f1c> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_6["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_7= freq_tbl(Micro_Ret["69_why_not_services"])
Filtro_7= tab_7[tab_7["frequency"]>1]
Filtro_index_7=Filtro_7.set_index("69_why_not_services")
Filtro_index_7
# Out:
#                                                     frequency  percentage  \
# 69_why_not_services
# No conozco los servicios                                    7    0.040936
# No quiero involucrarme con la tecnología                    7    0.040936
# No creo que represente grandes ingresos                     6    0.035088
# Es muy caro                                                 4    0.023392
# No conozco los servicios,No quiero involucrarme...          2    0.011696
#
#                                                     cumulative_perc
# 69_why_not_services
# No conozco los servicios                                   0.170732
# No quiero involucrarme con la tecnología                   0.341463
# No creo que represente grandes ingresos                    0.487805
# Es muy caro                                                0.585366
# No conozco los servicios,No quiero involucrarme...         0.634146

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_7["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-38-646e72f7fd35> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_7["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_8= freq_tbl(Micro_Ret["311_topups"])
Filtro_8= tab_8[tab_8["frequency"]>1]
Filtro_index_8=Filtro_8.set_index("311_topups")
Filtro_index_8
# Out:
#                                 frequency  percentage  cumulative_perc
# 311_topups
# Totalmente en desacuerdo               32    0.187135         0.561404
# Totalmente de acuerdo                  13    0.076023         0.789474
# Algo en desacuerdo                      4    0.023392         0.859649
# Algo de acuerdo                         4    0.023392         0.929825
# Ni de acuerdo ni en desacuerdo          4    0.023392         1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_8["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-41-9c5b93c7a9dd> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_8["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_9= freq_tbl(Micro_Ret["312_payment_of_utilities"])
Filtro_9= tab_9[tab_9["frequency"]>1]
Filtro_index_9=Filtro_9.set_index("312_payment_of_utilities")
Filtro_index_9

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_9["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-69d8c1cd05a8> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_9["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_10= freq_tbl(Micro_Ret["313_home_deliveries"])
Filtro_10= tab_10[tab_10["frequency"]>1]
Filtro_index_10=Filtro_10.set_index("313_home_deliveries")
Filtro_index_10
# Out:
#                                 frequency  percentage  cumulative_perc
# 313_home_deliveries
# Totalmente en desacuerdo               25    0.146199         0.431034
# Totalmente de acuerdo                  14    0.081871         0.672414
# Algo de acuerdo                        11    0.064327         0.862069
# Algo en desacuerdo                      5    0.029240         0.948276
# Ni de acuerdo ni en desacuerdo          3    0.017544         1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_10["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-efad0e907dd6> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_10["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_11= freq_tbl(Micro_Ret["314_reception_delivery_packages"])
Filtro_11= tab_11[tab_11["frequency"]>1]
Filtro_index_11=Filtro_11.set_index("314_reception_delivery_packages")
Filtro_index_11
# Out:
#                                  frequency  percentage  cumulative_perc
# 314_reception_delivery_packages
# Totalmente en desacuerdo                46    0.269006         0.676471
# Algo de acuerdo                          9    0.052632         0.808824
# Totalmente de acuerdo                    8    0.046784         0.926471
# Ni de acuerdo ni en desacuerdo           3    0.017544         0.970588
# Algo en desacuerdo                       2    0.011696         1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_11["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-ae719d9e15c5> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_11["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_12= freq_tbl(Micro_Ret["42_willingness_share_inventory_data_suppliers"])
Filtro_12= tab_12[tab_12["frequency"]>1]
Filtro_index_12=Filtro_12.set_index("42_willingness_share_inventory_data_suppliers")
Filtro_index_12
# Out:
#                                                frequency  percentage  \
# 42_willingness_share_inventory_data_suppliers
# Totalmente en desacuerdo                              49    0.286550
# Algo de acuerdo                                       13    0.076023
# Algo en desacuerdo                                     8    0.046784
# Ni de acuerdo ni en desacuerdo                         6    0.035088
# Totalmente de acuerdo                                  4    0.023392
#
#                                                cumulative_perc
# 42_willingness_share_inventory_data_suppliers
# Totalmente en desacuerdo                                0.6125
# Algo de acuerdo                                         0.7750
# Algo en desacuerdo                                      0.8750
# Ni de acuerdo ni en desacuerdo                          0.9500
# Totalmente de acuerdo                                   1.0000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_12["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-50-3fc4de1e83dd> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_12["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_13= freq_tbl(Micro_Ret["44_willingness_inventory_management_suppliers"])
Filtro_13= tab_13[tab_13["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_13=Filtro_13.set_index("44_willingness_inventory_management_suppliers")#ajustamos esta columna como una de tipo indice
Filtro_index_13
# Out:
#                                                frequency  percentage  \
# 44_willingness_inventory_management_suppliers
# Totalmente en desacuerdo                              58    0.339181
# Algo en desacuerdo                                     8    0.046784
# Ni de acuerdo ni en desacuerdo                         5    0.029240
# Algo de acuerdo                                        5    0.029240
# Totalmente de acuerdo                                  3    0.017544
#
#                                                cumulative_perc
# 44_willingness_inventory_management_suppliers
# Totalmente en desacuerdo                              0.734177
# Algo en desacuerdo                                    0.835443
# Ni de acuerdo ni en desacuerdo                        0.898734
# Algo de acuerdo                                       0.962025
# Totalmente de acuerdo                                 1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_13["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-52-49846186b7ac> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_13["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_14= freq_tbl(Micro_Ret["45_willingness_reorder_suppliers"])
Filtro_14= tab_14[tab_14["frequency"]>1]
Filtro_index_14=Filtro_14.set_index("45_willingness_reorder_suppliers")
Filtro_index_14
# Out:
#                                   frequency  percentage  cumulative_perc
# 45_willingness_reorder_suppliers
# Totalmente en desacuerdo                 40    0.233918         0.519481
# Algo de acuerdo                          12    0.070175         0.675325
# Algo en desacuerdo                       10    0.058480         0.805195
# Totalmente de acuerdo                     9    0.052632         0.922078
# Ni de acuerdo ni en desacuerdo            6    0.035088         1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_14["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-8fafe99a4617> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_14["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_15= freq_tbl(Micro_Ret["46_willingness_reorder_suppliers_variety"])
Filtro_15= tab_15[tab_15["frequency"]>1]
Filtro_index_15=Filtro_15.set_index("46_willingness_reorder_suppliers_variety")
Filtro_index_15
# Out:
#                                           frequency  percentage  \
# 46_willingness_reorder_suppliers_variety
# Totalmente en desacuerdo                         33    0.192982
# Totalmente de acuerdo                            15    0.087719
# Algo de acuerdo                                  14    0.081871
# Algo en desacuerdo                                7    0.040936
# Ni de acuerdo ni en desacuerdo                    5    0.029240
#
#                                           cumulative_perc
# 46_willingness_reorder_suppliers_variety
# Totalmente en desacuerdo                         0.445946
# Totalmente de acuerdo                            0.648649
# Algo de acuerdo                                  0.837838
# Algo en desacuerdo                               0.932432
# Ni de acuerdo ni en desacuerdo                   1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_15["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-56-7deb55d1c0c2> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_15["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_16= freq_tbl(Micro_Ret["47_willingness_reorder_suppliers_lower_prices"])
Filtro_16= tab_16[tab_16["frequency"]>1]
Filtro_index_16=Filtro_16.set_index("47_willingness_reorder_suppliers_lower_prices")
Filtro_index_16
# Out:
#                                                frequency  percentage  \
# 47_willingness_reorder_suppliers_lower_prices
# Totalmente en desacuerdo                              31    0.181287
# Algo de acuerdo                                       17    0.099415
# Totalmente de acuerdo                                 12    0.070175
# Algo en desacuerdo                                     5    0.029240
# Ni de acuerdo ni en desacuerdo                         4    0.023392
#
#                                                cumulative_perc
# 47_willingness_reorder_suppliers_lower_prices
# Totalmente en desacuerdo                              0.449275
# Algo de acuerdo                                       0.695652
# Totalmente de acuerdo                                 0.869565
# Algo en desacuerdo                                    0.942029
# Ni de acuerdo ni en desacuerdo                        1.000000

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index_16["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-58-68d34c0ed4a7> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index_16["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_17= freq_tbl(Micro_Ret["43_willingness_share_sales_data_suppliers"])
Filtro_17= tab_17[tab_17["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_17=Filtro_17.set_index("43_willingness_share_sales_data_suppliers")#ajustamos esta columna como una de tipo indice
Filtro_index_17
#Realizamos le pastel del Dataframe filtrado
Filtro_index_17["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-59-c1a53a6784a0> in <cell line: 8>()
#       6 Filtro_index_17
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_17["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_18= freq_tbl(Micro_Ret["58_willingness_share_sales_data_mse"])
Filtro_18= tab_18[tab_18["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_18=Filtro_18.set_index("58_willingness_share_sales_data_mse")#ajustamos esta columna como una de tipo indice
Filtro_index_18
#Realizamos le pastel del Dataframe filtrado
Filtro_index_18["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-60-36101f44bbcc> in <cell line: 8>()
#       6 Filtro_index_18
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_18["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_19= freq_tbl(Micro_Ret["59_willingness_share_sales_data_mse_better_prices"])
Filtro_19= tab_19[tab_19["frequency"]>1]
Filtro_index_19=Filtro_19.set_index("59_willingness_share_sales_data_mse_better_prices")
Filtro_index_19
#Realizamos le pastel del Dataframe filtrado
Filtro_index_19["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-61-9136ff0fe5e8> in <cell line: 8>()
#       6 Filtro_index_19
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_19["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_20= freq_tbl(Micro_Ret["185_place_orders_suppliers"])
Filtro_20= tab_20[tab_20["frequency"]>1]
Filtro_index_20=Filtro_20.set_index("185_place_orders_suppliers")
Filtro_index_20
#Realizamos le pastel del Dataframe filtrado
Filtro_index_20["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-aa94ab0d3fea> in <cell line: 8>()
#       6 Filtro_index_20
#       7 #Realizamos le pastel del Dataframe filtrado
# ----> 8 Filtro_index_20["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
#    1888     # https://github.com/python/importlib_metadata/issues/298
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1815             :context: close-figs
#    1816
# -> 1817             >>> n = 10000
#    1818             >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1819             ...                    'y': np.random.randn(n)})
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **RECOPILACION DE TIPOS DE GRAFICAS**

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
tab_7= freq_tbl(Micro_Ret[""])
Filtro_7= tab_7[tab_7["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_7=Filtro_7.set_index("")#ajustamos esta columna como una de tipo indice
#Filtro_index_7
#Realizamos le pastel del Dataframe filtrado
Filtro_index_7["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")#Ajusto indice de mi DATAFRAME
Filtro_index=Filtro1.set_index("214_customer_relationship_tools")#ajustamos esta columna como una de tipo indice
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind= "bar", width=1, figsize=(10,4))
plt.title("Herramientas de relación con los clientes")
plt.xlabel("Tipo de herramienta")
plt.ylabel("Frecuencia")
#Realizamos el grafico de dispersion
Filtro_index.plot("frequency", "cumulative_perc", kind= "scatter")
#Realizamos el grafico de area del Dataframe filtrado
Filtro_index.plot(kind= "area", figsize=(10,4), alpha=0.5)
#Realizamos le pastel del Dataframe filtrado
Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             #  the TypeError.
# -> 3802             self._check_indexing_error(key)
#    3803             raise
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-f95fb5034332> in <cell line: 3>()
#       1 #Obtengo un analisis univariado de las variables categoricas, una slecionada
#       2 #Obtengo un analisis univariado de las variables categoricas, una en especifico
# ----> 3 tab_7= freq_tbl(Micro_Ret[""])
#       4 Filtro_7= tab_7[tab_7["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
#       5 Filtro_index_7=Filtro_7.set_index("")#ajustamos esta columna como una de tipo indice
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805
#    3806             # this is a cached value, mark it so
# -> 3807             result._set_as_cached(label, self)
#    3808             return result
#    3809
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802             self._check_indexing_error(key)
#    3803             raise
# -> 3804
#    3805     _index_shared_docs[
#    3806         "get_indexer"
#
# KeyError: ''
